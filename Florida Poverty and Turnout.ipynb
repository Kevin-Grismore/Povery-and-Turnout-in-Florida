# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pysal.viz.mapclassify as mc
from matplotlib.colors import rgb2hex
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\pysal\explore\segregation\network\network.py:16: UserWarning: You need pandana and urbanaccess to work with segregation's network module
# You can install them with  `pip install urbanaccess pandana` or `conda install -c udst pandana urbanaccess`
#   "You need pandana and urbanaccess to work with segregation's network module\n"
# C:\Users\kevin\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# os.getcwd()

# %%
os.chdir('Data')

# %%
os.listdir()
# Out:
# ['Florida', 'FLPoverty.csv', 'flpoverty2018.csv', 'FLTurnout.csv']

# %%
poverty = pd.read_csv('FLPoverty.csv')

# %%
poverty['ccode'] = poverty['ccode'].astype(float)
poverty.head()
# Out:
#      County  pov2010  pov2012  pov2014  pov2016  pov2018  ccode
# 0   Alachua     23.6     23.8     25.4     24.2     21.2    1.0
# 1     Baker     17.0     17.0     18.6     18.5     15.3    3.0
# 2       Bay     12.4     13.3     14.8     15.6     14.9    5.0
# 3  Bradford     16.0     20.1     19.3     19.3     19.1    7.0
# 4   Brevard     10.5     12.5     14.0     14.0     12.4    9.0

# %%
turnout = pd.read_csv("FLTurnout.csv")

# %%
turnout['ccode'] = turnout['ccode'].astype(float)
for i, row in turnout.iterrows():
    if row['trn2010'] == 0:
        turnout.loc[i, 'trn2010'] = np.nan
    if row['trn2012'] == 0:
        turnout.loc[i, 'trn2012'] = np.nan
    if row['trn2014'] == 0:
        turnout.loc[i, 'trn2014'] = np.nan
    if row['trn2016'] == 0:
        turnout.loc[i, 'trn2016'] = np.nan
    if row['trn2018'] == 0:
        turnout.loc[i, 'trn2018'] = np.nan
turnout.head()
# Out:
#      County  trn2010  trn2012  trn2014  trn2016  trn2018  ccode
# 0   Alachua    49.41    73.40    50.20    73.60    62.41    1.0
# 1     Baker    58.17    81.80    61.79    84.30    70.18    3.0
# 2       Bay    51.41    71.22    51.14    75.17    52.87    5.0
# 3  Bradford      NaN      NaN    55.44    76.25    64.95    7.0
# 4   Brevard    55.88    75.60    59.47    77.82    67.26    9.0

# %%
os.chdir('Florida')
os.listdir()
# Out:
# ['1000-largest-us-cities-by-population-with-geographic-coordinates.dbf',
#  '1000-largest-us-cities-by-population-with-geographic-coordinates.prj',
#  '1000-largest-us-cities-by-population-with-geographic-coordinates.shp',
#  '1000-largest-us-cities-by-population-with-geographic-coordinates.shx',
#  'City_Locations.cpg',
#  'City_Locations.dbf',
#  'City_Locations.prj',
#  'City_Locations.shp',
#  'City_Locations.shx',
#  'City_Locations.xml',
#  'Florida_Counties.cpg',
#  'Florida_Counties.dbf',
#  'Florida_Counties.prj',
#  'Florida_Counties.shp',
#  'Florida_Counties.shx',
#  'Florida_Counties.xml']

# %%
fl_counties = gpd.read_file('Florida_Counties.shp')

# %%
fl_counties.head()
# Out:
#    OBJECTID  DEPCODE COUNTY COUNTYNAME                 DATESTAMP  \
# 0         1       21    041  GILCHRIST  2000-05-16T00:00:00.000Z
# 1         2       54    107     PUTNAM  2000-05-16T00:00:00.000Z
# 2         3       62    123     TAYLOR  2000-05-16T00:00:00.000Z
# 3         4       46    091   OKALOOSA  2000-05-16T00:00:00.000Z
# 4         5        7    013    CALHOUN  2000-05-16T00:00:00.000Z
#
#      ShapeSTAre    ShapeSTLen  \
# 0  9.908353e+09  4.873000e+05
# 1  2.305869e+10  7.629677e+05
# 2  2.891747e+10  8.772527e+05
# 3  2.562159e+10  1.087058e+06
# 4  1.604809e+10  6.313440e+05
#
#                                             geometry
# 0  POLYGON ((-82.65813600527831 29.83028106592836...
# 1  POLYGON ((-81.58084263191225 29.83955869988373...
# 2  (POLYGON ((-83.73036687278116 30.3035764144186...
# 3  (POLYGON ((-86.39159408384468 30.6497039172779...
# 4  POLYGON ((-84.93265667941331 30.60636534524649...

# %%
fl_counties['COUNTY'] = fl_counties['COUNTY'].astype(float)
fl_counties.head()
# Out:
#    OBJECTID  DEPCODE  COUNTY COUNTYNAME                 DATESTAMP  \
# 0         1       21    41.0  GILCHRIST  2000-05-16T00:00:00.000Z
# 1         2       54   107.0     PUTNAM  2000-05-16T00:00:00.000Z
# 2         3       62   123.0     TAYLOR  2000-05-16T00:00:00.000Z
# 3         4       46    91.0   OKALOOSA  2000-05-16T00:00:00.000Z
# 4         5        7    13.0    CALHOUN  2000-05-16T00:00:00.000Z
#
#      ShapeSTAre    ShapeSTLen  \
# 0  9.908353e+09  4.873000e+05
# 1  2.305869e+10  7.629677e+05
# 2  2.891747e+10  8.772527e+05
# 3  2.562159e+10  1.087058e+06
# 4  1.604809e+10  6.313440e+05
#
#                                             geometry
# 0  POLYGON ((-82.65813600527831 29.83028106592836...
# 1  POLYGON ((-81.58084263191225 29.83955869988373...
# 2  (POLYGON ((-83.73036687278116 30.3035764144186...
# 3  (POLYGON ((-86.39159408384468 30.6497039172779...
# 4  POLYGON ((-84.93265667941331 30.60636534524649...

# %%
fl_counties.plot()

# %%
us_cities = gpd.read_file('1000-largest-us-cities-by-population-with-geographic-coordinates.shp')

# %%
us_cities.head()
# Out:
#          city   rank           state  growth_from  population  \
# 0  Marysville  552.0      Washington        115.7     63269.0
# 1      Perris  466.0      California         98.7     72326.0
# 2   Cleveland   48.0            Ohio        -18.1    390113.0
# 3   Worcester  129.0   Massachusetts          5.8    182544.0
# 4    Columbia  192.0  South Carolina         11.7    133358.0
#
#                           geometry
# 0  POINT (-122.1770818 48.0517637)
# 1  POINT (-117.2286478 33.7825194)
# 2     POINT (-81.6943605 41.49932)
# 3   POINT (-71.8022934 42.2625932)
# 4   POINT (-81.0348144 34.0007104)

# %%
us_cities.plot()

# %%
fl_cities = us_cities.loc[us_cities['state'] == 'Florida']
fl_cities_big = fl_cities.loc[fl_cities['population'] >= 250000.0]

# %%
ax = fl_cities_big.plot()

for x, y, label in zip(fl_cities_big.geometry.x, fl_cities_big.geometry.y, fl_cities_big.city):
    ax.annotate(label, xy=(x, y), xytext=(3,3), textcoords="offset points")

# %%
fl_counties_pov = fl_counties.merge(poverty, left_on = 'COUNTY', right_on = 'ccode', how = 'left')

# %%
fl_counties_pov.head(67)
# Out:
#     OBJECTID  DEPCODE  COUNTY    COUNTYNAME                 DATESTAMP  \
# 0          1       21    41.0     GILCHRIST  2000-05-16T00:00:00.000Z
# 1          2       54   107.0        PUTNAM  2000-05-16T00:00:00.000Z
# 2          3       62   123.0        TAYLOR  2000-05-16T00:00:00.000Z
# 3          4       46    91.0      OKALOOSA  2000-05-16T00:00:00.000Z
# 4          5        7    13.0       CALHOUN  2000-05-16T00:00:00.000Z
# 5          6       50    99.0    PALM BEACH  2000-05-16T00:00:00.000Z
# 6          7       56   111.0     ST. LUCIE  2000-05-16T00:00:00.000Z
# 7          8       51   101.0         PASCO  2000-05-16T00:00:00.000Z
# 8          9       20    39.0       GADSDEN  2000-05-16T00:00:00.000Z
# 9         10       37    73.0          LEON  2000-05-16T00:00:00.000Z
# 10        11       33    65.0     JEFFERSON  2000-05-16T00:00:00.000Z
# 11        12       40    79.0       MADISON  2000-05-16T00:00:00.000Z
# 12        13       39    77.0       LIBERTY  2000-05-16T00:00:00.000Z
# 13        14       24    47.0      HAMILTON  2000-05-16T00:00:00.000Z
# 14        15        3     5.0           BAY  2000-05-16T00:00:00.000Z
# 15        16       12    23.0      COLUMBIA  2000-05-16T00:00:00.000Z
# 16        17        2     3.0         BAKER  2000-05-16T00:00:00.000Z
# 17        18       30    59.0        HOLMES  2000-05-16T00:00:00.000Z
# 18        19       43    85.0        MARTIN  2000-05-16T00:00:00.000Z
# 19        20       29    57.0  HILLSBOROUGH  2000-05-16T00:00:00.000Z
# 20        21       41    81.0       MANATEE  2000-05-16T00:00:00.000Z
# 21        22       10    19.0          CLAY  2000-05-16T00:00:00.000Z
# 22        23       25    49.0        HARDEE  2000-05-16T00:00:00.000Z
# 23        24       42    83.0        MARION  2000-05-16T00:00:00.000Z
# 24        25       64   127.0       VOLUSIA  2000-05-16T00:00:00.000Z
# 25        26       15    29.0         DIXIE  2000-05-16T00:00:00.000Z
# 26        27       35    69.0          LAKE  2000-05-16T00:00:00.000Z
# 27        28       38    75.0          LEVY  2000-05-16T00:00:00.000Z
# 28        29       60   119.0        SUMTER  2000-05-16T00:00:00.000Z
# 29        30       59   117.0      SEMINOLE  2000-05-16T00:00:00.000Z
# ..       ...      ...     ...           ...                       ...
# 37        38       23    45.0          GULF  2000-05-16T00:00:00.000Z
# 38        39       63   125.0         UNION  2000-05-16T00:00:00.000Z
# 39        40        4     7.0      BRADFORD  2000-05-16T00:00:00.000Z
# 40        41       65   129.0       WAKULLA  2000-05-16T00:00:00.000Z
# 41        42        5     9.0       BREVARD  2000-05-16T00:00:00.000Z
# 42        43       53   105.0          POLK  2000-05-16T00:00:00.000Z
# 43        44       49    97.0       OSCEOLA  2000-05-16T00:00:00.000Z
# 44        45       28    55.0     HIGHLANDS  2000-05-16T00:00:00.000Z
# 45        46       36    71.0           LEE  2000-05-16T00:00:00.000Z
# 46        47       11    21.0       COLLIER  2000-05-16T00:00:00.000Z
# 47        48       13    25.0          DADE  2000-05-16T00:00:00.000Z
# 48        49       44    87.0        MONROE  2000-05-16T00:00:00.000Z
# 49        50       57   113.0    SANTA ROSA  2000-05-16T00:00:00.000Z
# 50        51       66   131.0        WALTON  2000-05-16T00:00:00.000Z
# 51        52       32    63.0       JACKSON  2000-05-16T00:00:00.000Z
# 52        53       67   133.0    WASHINGTON  2000-05-16T00:00:00.000Z
# 53        54       45    89.0        NASSAU  2000-05-16T00:00:00.000Z
# 54        55       22    43.0        GLADES  2000-05-16T00:00:00.000Z
# 55        56        8    15.0     CHARLOTTE  2000-05-16T00:00:00.000Z
# 56        57       58   115.0      SARASOTA  2000-05-16T00:00:00.000Z
# 57        58       14    27.0        DESOTO  2000-05-16T00:00:00.000Z
# 58        59       18    35.0       FLAGLER  2000-05-16T00:00:00.000Z
# 59        60       26    51.0        HENDRY  2000-05-16T00:00:00.000Z
# 60        61       31    61.0  INDIAN RIVER  2000-05-16T00:00:00.000Z
# 61        62        6    11.0       BROWARD  2000-05-16T00:00:00.000Z
# 62        63       17    33.0      ESCAMBIA  2000-05-16T00:00:00.000Z
# 63        64       47    93.0    OKEECHOBEE  2000-05-16T00:00:00.000Z
# 64        65       19    37.0      FRANKLIN  2000-05-16T00:00:00.000Z
# 65        66        1     1.0       ALACHUA  2000-05-16T00:00:00.000Z
# 66        67       55   109.0     ST. JOHNS  2000-05-16T00:00:00.000Z
#
#       ShapeSTAre    ShapeSTLen  \
# 0   9.908353e+09  4.873000e+05
# 1   2.305869e+10  7.629677e+05
# 2   2.891747e+10  8.772527e+05
# 3   2.562159e+10  1.087058e+06
# 4   1.604809e+10  6.313440e+05
# 5   6.149159e+10  1.522727e+06
# 6   1.614948e+10  8.295187e+05
# 7   2.126081e+10  7.393906e+05
# 8   1.474496e+10  6.736124e+05
# 9   1.958402e+10  8.079897e+05
# 10  1.703340e+10  7.494661e+05
# 11  1.995427e+10  7.194222e+05
# 12  2.354530e+10  1.014157e+06
# 13  1.447796e+10  7.630344e+05
# 14  2.084232e+10  1.834701e+06
# 15  2.226649e+10  9.054175e+05
# 16  1.636216e+10  6.027173e+05
# 17  1.351483e+10  5.772794e+05
# 18  1.816321e+10  1.014295e+06
# 19  2.956403e+10  1.177197e+06
# 20  2.094089e+10  1.218253e+06
# 21  1.794850e+10  6.031178e+05
# 22  1.779280e+10  5.432615e+05
# 23  4.633421e+10  1.151394e+06
# 24  3.364565e+10  1.837936e+06
# 25  1.963495e+10  7.718929e+05
# 26  3.224552e+10  1.085414e+06
# 27  3.122285e+10  1.113561e+06
# 28  1.617104e+10  7.519140e+05
# 29  9.616121e+09  5.203654e+05
# ..           ...           ...
# 37  1.585751e+10  8.502724e+05
# 38  6.963394e+09  4.206436e+05
# 39  8.359863e+09  5.483267e+05
# 40  1.702251e+10  9.167339e+05
# 41  2.893695e+10  2.600567e+06
# 42  5.603973e+10  1.273588e+06
# 43  4.197437e+10  1.149911e+06
# 44  3.085853e+10  9.732572e+05
# 45  2.273452e+10  1.913267e+06
# 46  5.594121e+10  1.903355e+06
# 47  5.507338e+10  1.774363e+06
# 48  2.830854e+10  4.591182e+06
# 49  2.810927e+10  1.198564e+06
# 50  2.926099e+10  1.216747e+06
# 51  2.645767e+10  7.352876e+05
# 52  1.721229e+10  8.010119e+05
# 53  1.766834e+10  1.275145e+06
# 54  2.747053e+10  7.769734e+05
# 55  1.964766e+10  1.306869e+06
# 56  1.624460e+10  8.664802e+05
# 57  1.781156e+10  5.526117e+05
# 58  1.393648e+10  7.233006e+05
# 59  3.316425e+10  9.520533e+05
# 60  1.421105e+10  7.680810e+05
# 61  3.383955e+10  9.580261e+05
# 62  1.915206e+10  1.448408e+06
# 63  2.484427e+10  8.939740e+05
# 64  1.558955e+10  1.467125e+06
# 65  2.702324e+10  8.927266e+05
# 66  1.784792e+10  1.130720e+06
#
#                                              geometry        County  pov2010  \
# 0   POLYGON ((-82.65813600527831 29.83028106592836...     Gilchrist     20.1
# 1   POLYGON ((-81.58084263191225 29.83955869988373...        Putnam     23.3
# 2   (POLYGON ((-83.73036687278116 30.3035764144186...        Taylor     19.1
# 3   (POLYGON ((-86.39159408384468 30.6497039172779...      Okaloosa     10.6
# 4   POLYGON ((-84.93265667941331 30.60636534524649...       Calhoun     21.1
# 5   (POLYGON ((-80.11189805095071 26.9706879617934...    Palm Beach     12.2
# 6   (POLYGON ((-80.23991747525355 27.2651852647402...     St. Lucie     13.7
# 7   (POLYGON ((-82.05534449850346 28.4489598075182...         Pasco     12.3
# 8   POLYGON ((-84.28257872708906 30.68505957879821...       Gadsden     27.6
# 9   POLYGON ((-84.00743103413359 30.67206747675587...          Leon     22.0
# 10  POLYGON ((-83.61163544078418 30.65134848769744...     Jefferson     18.7
# 11  POLYGON ((-83.30933621413645 30.63457807703418...       Madison     21.0
# 12  POLYGON ((-84.64636375374739 30.38835916642507...       Liberty     15.8
# 13  POLYGON ((-82.68928799880388 30.59750432563009...      Hamilton     21.4
# 14  (POLYGON ((-85.38551240490355 30.5001848879283...           Bay     12.4
# 15  POLYGON ((-82.45968512474653 30.5823831674325,...      Columbia     15.6
# 16  POLYGON ((-82.05011944804005 30.36232753764464...         Baker     17.0
# 17  POLYGON ((-85.49917112757134 30.99561232848277...        Holmes     19.9
# 18  (POLYGON ((-80.28442316848732 27.2055345306220...        Martin     10.4
# 19  (POLYGON ((-82.42818039960586 28.1712291657317...  Hillsborough     14.2
# 20  (POLYGON ((-82.53142556031813 27.6455373901910...       Manatee     12.8
# 21  POLYGON ((-81.68007516544645 30.12155088244222...          Clay      8.5
# 22  POLYGON ((-81.56330726490449 27.64667938877338...        Hardee     26.1
# 23  POLYGON ((-81.68072399321659 29.32456560258519...        Marion     15.3
# 24  (POLYGON ((-81.09705070957313 29.3517975685237...       Volusia     13.8
# 25  (POLYGON ((-83.24986280843204 29.8230241429827...         Dixie     15.5
# 26  POLYGON ((-81.36723192073531 28.87903949658943...          Lake     11.0
# 27  (POLYGON ((-82.92321055599521 29.5908868753411...          Levy     21.6
# 28  POLYGON ((-81.95433194295875 28.96002352989874...        Sumter     11.2
# 29  POLYGON ((-81.03481773659463 28.71969292894357...      Seminole      9.8
# ..                                                ...           ...      ...
# 37  POLYGON ((-85.11577991027924 30.19981618322079...          Gulf     19.5
# 38  POLYGON ((-82.14257733477386 30.14285049936788...         Union     21.3
# 39  POLYGON ((-82.04938555543274 30.14322318104236...      Bradford     16.0
# 40  (POLYGON ((-84.41196678082933 30.3024418754899...       Wakulla     12.5
# 41  (POLYGON ((-80.80666189428287 28.6141335175333...       Brevard     10.5
# 42  POLYGON ((-81.65736657124391 28.34704469797485...          Polk     15.2
# 43  POLYGON ((-80.86326914498791 28.34771233868008...       Osceola     13.3
# 44  POLYGON ((-81.14219045179775 27.64320548895666...     Highlands     16.9
# 45  (POLYGON ((-82.00271116792641 26.7700909979102...           Lee     12.0
# 46  (POLYGON ((-81.27162486421831 26.5169365678806...       Collier     12.2
# 47  (POLYGON ((-80.87313622261388 25.9794447746445...    Miami-Dade     17.2
# 48  (POLYGON ((-80.87319099402116 25.8056804456275...        Monroe     10.8
# 49  POLYGON ((-87.1626496528602 30.99702072557957,...    Santa Rosa     11.3
# 50  POLYGON ((-86.03523270570004 30.98824885033508...        Walton     14.6
# 51  POLYGON ((-84.86454589289002 30.71148075275003...       Jackson     19.7
# 52  POLYGON ((-85.43543358092634 30.56726743279475...    Washington     19.3
# 53  (POLYGON ((-81.89150587604259 30.8168275494847...        Nassau      9.3
# 54  POLYGON ((-80.94082370652353 27.20606712168216...        Glades     19.6
# 55  (POLYGON ((-81.97884330940181 27.0351741236586...     Charlotte     10.5
# 56  (POLYGON ((-82.52940806611684 27.3886696393451...      Sarasota     10.5
# 57  POLYGON ((-81.56373292278376 27.34062441339971...        DeSoto     26.9
# 58  (POLYGON ((-81.25709506494681 29.6640926449169...       Flagler     11.9
# 59  POLYGON ((-80.88152941983728 26.33373840838943...        Hendry     26.4
# 60  (POLYGON ((-80.47329564840328 27.8250369856646...  Indian River     12.6
# 61  (POLYGON ((-80.22679891559656 26.3347843608116...       Broward     12.3
# 62  (POLYGON ((-87.23130787550615 30.9969721265442...      Escambia     16.4
# 63  POLYGON ((-80.67932073775449 27.55849290183577...    Okeechobee     19.7
# 64  (POLYGON ((-84.66713043702889 30.0116750837599...      Franklin     25.6
# 65  POLYGON ((-82.41869270004275 29.92298363381924...       Alachua     23.6
# 66  (POLYGON ((-81.37788144125285 30.1078996789115...     St. Johns      9.1
#
#     pov2012  pov2014  pov2016  pov2018  ccode
# 0      21.9     24.9     23.8     16.1   41.0
# 1      25.5     26.5     27.0     26.3  107.0
# 2      19.1     13.8     14.8     23.8  123.0
# 3      12.5     13.7     12.0     10.9   91.0
# 4      24.8     22.5     13.1     21.1   13.0
# 5      14.0     14.6     13.9     11.8   99.0
# 6      16.6     18.4     17.9      9.2  111.0
# 7      13.7     14.3     13.6     13.0  101.0
# 8      29.5     27.2     25.6     23.1   39.0
# 9      22.8     23.7     21.3     18.0   73.0
# 10     18.8     17.1     15.8     17.7   65.0
# 11     21.6     22.2     28.5     28.3   79.0
# 12     22.2     20.1     16.9     23.0   77.0
# 13     22.6     28.6     27.0     24.0   47.0
# 14     13.3     14.8     15.6     14.9    5.0
# 15     19.7     20.0     19.4     16.5   23.0
# 16     17.0     18.6     18.5     15.3    3.0
# 17     22.6     26.6     26.0     21.2   59.0
# 18     12.5     12.0     11.8     10.9   85.0
# 19     16.5     17.2     16.4     15.5   57.0
# 20     14.5     14.9     14.3     10.8   81.0
# 21     10.1     10.5     10.2      9.9   19.0
# 22     29.7     30.8     26.4     23.3   49.0
# 23     17.3     18.3     18.2     16.2   83.0
# 24     16.0     17.6     16.7     15.2  127.0
# 25     16.3     18.9     21.5     24.4   29.0
# 26     13.0     14.3     13.5     12.6   69.0
# 27     22.8     24.0     22.2     20.8   75.0
# 28     11.7     10.9      9.9      9.1  119.0
# 29     10.8     11.6     12.1     12.8  117.0
# ..      ...      ...      ...      ...    ...
# 37     18.8     16.4     15.3     21.6   45.0
# 38     18.7     19.0     22.4     22.2  125.0
# 39     20.1     19.3     19.3     19.1    7.0
# 40     14.1     13.4     14.3     12.9  129.0
# 41     12.5     14.0     14.0     12.4    9.0
# 42     17.5     18.5     17.7     16.1  105.0
# 43     16.0     18.3     19.5     14.0   97.0
# 44     19.0     19.2     19.4     19.8   55.0
# 45     14.5     16.0     15.5     11.8   71.0
# 46     14.0     14.4     13.2     11.7   21.0
# 47     19.1     20.5     19.9     16.7   25.0
# 48     12.1     13.9     13.0     11.8   87.0
# 49     11.1     12.2     12.3     11.2  113.0
# 50     16.4     17.7     17.4     15.9  131.0
# 51     15.5     21.3     22.9     18.0   63.0
# 52     20.9     19.5     20.5     21.1  133.0
# 53     11.1     12.6     12.7      9.1   89.0
# 54     25.3     24.3     20.7     18.9   43.0
# 55     11.9     12.7     12.4     10.8   15.0
# 56     11.6     11.8     11.0      8.3  115.0
# 57     26.8     30.5     29.9     26.1   27.0
# 58     14.4     16.4     13.2     12.0   35.0
# 59     28.7     26.8     26.3     23.9   51.0
# 60     14.8     15.4     14.1     10.6   61.0
# 61     13.5     14.6     14.4     13.1   11.0
# 62     17.8     17.1     14.7     16.4   33.0
# 63     27.2     27.9     25.3     21.8   93.0
# 64     22.2     23.0     20.7     21.3   37.0
# 65     23.8     25.4     24.2     21.2    1.0
# 66      9.8      9.7      9.0     10.2  109.0
#
# [67 rows x 15 columns]

# %%
fl_counties_pov.describe()
# Out:
#         OBJECTID    DEPCODE      COUNTY    ShapeSTAre    ShapeSTLen  \
# count  67.000000  67.000000   67.000000  6.700000e+01  6.700000e+01
# mean   34.000000  34.000000   67.000000  2.342932e+10  1.048655e+06
# std    19.485037  19.485037   38.970074  1.149607e+10  5.982756e+05
# min     1.000000   1.000000    1.000000  6.963394e+09  4.206436e+05
# 25%    17.500000  17.500000   34.000000  1.620782e+10  7.373391e+05
# 50%    34.000000  34.000000   67.000000  1.964766e+10  8.939740e+05
# 75%    50.500000  50.500000  100.000000  2.820891e+10  1.172507e+06
# max    67.000000  67.000000  133.000000  6.149159e+10  4.591182e+06
#
#          pov2010    pov2012    pov2014    pov2016    pov2018       ccode
# count  67.000000  67.000000  67.000000  67.000000  67.000000   67.000000
# mean   15.998507  17.728358  18.519403  17.777612  16.562687   67.000000
# std     4.931639   5.070378   5.204143   5.062273   5.112428   38.970074
# min     8.500000   9.800000   9.700000   9.000000   8.300000    1.000000
# 25%    12.150000  13.850000  14.350000  13.950000  12.100000   34.000000
# 50%    15.200000  16.500000  17.700000  16.900000  15.900000   67.000000
# 75%    19.650000  21.750000  22.350000  21.000000  21.150000  100.000000
# max    27.600000  29.700000  30.800000  29.900000  28.300000  133.000000

# %%
fl_counties_trn = fl_counties.merge(turnout, left_on = 'COUNTY', right_on = 'ccode', how = 'left')

# %%
fl_counties_trn.head()
# Out:
#    OBJECTID  DEPCODE  COUNTY COUNTYNAME                 DATESTAMP  \
# 0         1       21    41.0  GILCHRIST  2000-05-16T00:00:00.000Z
# 1         2       54   107.0     PUTNAM  2000-05-16T00:00:00.000Z
# 2         3       62   123.0     TAYLOR  2000-05-16T00:00:00.000Z
# 3         4       46    91.0   OKALOOSA  2000-05-16T00:00:00.000Z
# 4         5        7    13.0    CALHOUN  2000-05-16T00:00:00.000Z
#
#      ShapeSTAre    ShapeSTLen  \
# 0  9.908353e+09  4.873000e+05
# 1  2.305869e+10  7.629677e+05
# 2  2.891747e+10  8.772527e+05
# 3  2.562159e+10  1.087058e+06
# 4  1.604809e+10  6.313440e+05
#
#                                             geometry     County  trn2010  \
# 0  POLYGON ((-82.65813600527831 29.83028106592836...  Gilchrist    50.40
# 1  POLYGON ((-81.58084263191225 29.83955869988373...      Put0m    49.50
# 2  (POLYGON ((-83.73036687278116 30.3035764144186...     Taylor      NaN
# 3  (POLYGON ((-86.39159408384468 30.6497039172779...   Okaloosa    48.41
# 4  POLYGON ((-84.93265667941331 30.60636534524649...    Calhoun    51.77
#
#    trn2012  trn2014  trn2016  trn2018  ccode
# 0    71.95    54.56    74.55    63.07   41.0
# 1    72.70    51.00    70.62    59.96  107.0
# 2      NaN    55.86    76.47    65.89  123.0
# 3    73.78    49.85    75.70    62.50   91.0
# 4    75.28    50.95    72.09    53.53   13.0

# %%
for i, row in fl_counties_trn.iterrows():
    if row['trn2010'] == 0:
        fl_counties_trn.loc[i, 'trn2010'] = np.nan
    if row['trn2012'] == 0:
        fl_counties_trn.loc[i, 'trn2012'] = np.nan
    if row['trn2014'] == 0:
        fl_counties_trn.loc[i, 'trn2014'] = np.nan
    if row['trn2016'] == 0:
        fl_counties_trn.loc[i, 'trn2016'] = np.nan
    if row['trn2018'] == 0:
        fl_counties_trn.loc[i, 'trn2018'] = np.nan
        
fl_counties_trn.head()
# Out:
#    OBJECTID  DEPCODE  COUNTY COUNTYNAME                 DATESTAMP  \
# 0         1       21    41.0  GILCHRIST  2000-05-16T00:00:00.000Z
# 1         2       54   107.0     PUTNAM  2000-05-16T00:00:00.000Z
# 2         3       62   123.0     TAYLOR  2000-05-16T00:00:00.000Z
# 3         4       46    91.0   OKALOOSA  2000-05-16T00:00:00.000Z
# 4         5        7    13.0    CALHOUN  2000-05-16T00:00:00.000Z
#
#      ShapeSTAre    ShapeSTLen  \
# 0  9.908353e+09  4.873000e+05
# 1  2.305869e+10  7.629677e+05
# 2  2.891747e+10  8.772527e+05
# 3  2.562159e+10  1.087058e+06
# 4  1.604809e+10  6.313440e+05
#
#                                             geometry     County  trn2010  \
# 0  POLYGON ((-82.65813600527831 29.83028106592836...  Gilchrist    50.40
# 1  POLYGON ((-81.58084263191225 29.83955869988373...      Put0m    49.50
# 2  (POLYGON ((-83.73036687278116 30.3035764144186...     Taylor      NaN
# 3  (POLYGON ((-86.39159408384468 30.6497039172779...   Okaloosa    48.41
# 4  POLYGON ((-84.93265667941331 30.60636534524649...    Calhoun    51.77
#
#    trn2012  trn2014  trn2016  trn2018  ccode
# 0    71.95    54.56    74.55    63.07   41.0
# 1    72.70    51.00    70.62    59.96  107.0
# 2      NaN    55.86    76.47    65.89  123.0
# 3    73.78    49.85    75.70    62.50   91.0
# 4    75.28    50.95    72.09    53.53   13.0

# %%
turnout_ds = turnout.describe()

# %%
povplot = poverty.drop(columns = ['ccode'])
povplot = povplot.set_index('County').T
povplot = povplot.rename(index={'pov2010':'2010', 'pov2012':'2012', 'pov2014':'2014', 'pov2016':'2016', 'pov2018':'2018'})
fig, ax = plt.subplots(figsize = (12, 12))

mean = poverty.describe()
mean = mean.drop(columns = ['ccode'])
mean = mean.iloc[1]

mean = mean.rename(index={'pov2010':'2010', 'pov2012':'2012', 'pov2014':'2014', 'pov2016':'2016', 'pov2018':'2018'})


povplot.plot.line(legend = False)
mean.plot.line(legend = True, linewidth = 10, color = 'red')
ax.set_xlabel("Year")
ax.set_ylabel("Poverty %")
plt.title("Florida Poverty % by County")
# Out:
# Text(0.5, 1.0, 'Florida Poverty % by County')

# %%
trnplot = turnout.drop(columns = ['ccode'])
trnplot.head()
# Out:
#      County  trn2010  trn2012  trn2014  trn2016  trn2018
# 0   Alachua    49.41    73.40    50.20    73.60    62.41
# 1     Baker    58.17    81.80    61.79    84.30    70.18
# 2       Bay    51.41    71.22    51.14    75.17    52.87
# 3  Bradford      NaN      NaN    55.44    76.25    64.95
# 4   Brevard    55.88    75.60    59.47    77.82    67.26

# %%
for i, row in trnplot.iterrows():
    if row['trn2010'] == 0:
        trnplot.loc[i, 'trn2010'] = np.nan
    if row['trn2012'] == 0:
        trnplot.loc[i, 'trn2012'] = np.nan
    if row['trn2014'] == 0:
        trnplot.loc[i, 'trn2014'] = np.nan
    if row['trn2016'] == 0:
        trnplot.loc[i, 'trn2016'] = np.nan
    if row['trn2018'] == 0:
        trnplot.loc[i, 'trn2018'] = np.nan

trnplot = trnplot.set_index('County').T
trnplot = trnplot.rename(index={'trn2010':'2010', 'trn2012':'2012', 'trn2014':'2014', 'trn2016':'2016', 'trn2018':'2018'})

# %%
turnout_ds = turnout.describe()
turnout_ds.head()
# Out:
#          trn2010    trn2012    trn2014    trn2016    trn2018      ccode
# count  43.000000  46.000000  60.000000  61.000000  66.000000  67.000000
# mean   51.834651  72.983913  53.777333  74.740820  62.771667  67.000000
# std     4.833928   4.445945   6.100381   3.950502   5.489694  38.970074
# min    41.000000  59.800000  40.850000  64.470000  50.480000   1.000000
# 25%    49.295000  70.625000  49.947500  72.890000  59.742500  34.000000

# %%
fig, ax = plt.subplots()

trnplot.plot.line(legend = False)
mean = turnout_ds.drop(columns = ['ccode'])
mean = mean.iloc[1]
mean = mean.rename(index={'trn2010':'2010', 'trn2012':'2012', 'trn2014':'2014', 'trn2016':'2016', 'trn2018':'2018'})
mean.plot.line(linewidth = 10, color = 'red', legend = 'TRUE')

ax.set_xlabel("Year")
ax.set_ylabel("Turnout %")
plt.title("Florida Turnout % by County")
# Out:
# Text(0.5, 1.0, 'Florida Turnout % by County')

# %%
# categorize the numerical column
k = 6
quantiles = mc.Quantiles(fl_counties_trn.trn2010.dropna(), k=k)
fl_counties_trn['qnt2010'] = quantiles.find_bin(fl_counties_trn.trn2010).astype('str')

fl_counties_trn.loc[fl_counties_trn.trn2010.isnull(), 'qnt2010'] = 'No Data'

# add grey to a colormap to represent missing value
cmap = plt.cm.get_cmap('RdYlGn', k)
cmap_list = [rgb2hex(cmap(i)) for i in range(cmap.N)]
cmap_list.append('grey')
cmap_with_grey = colors.ListedColormap(cmap_list)

fig, ax = plt.subplots(figsize = (12,12))
ax.set_aspect('equal')
fl_counties_trn.plot(ax = ax, column='qnt2010', cmap = cmap_with_grey, edgecolor='black', legend=True)
fl_counties_pov[fl_counties_pov["pov2010"] >= 20].plot(ax = ax, facecolor='none', edgecolor = 'black', hatch="//")
fl_cities_big.plot(ax = ax, facecolor = 'black')

ax.set_facecolor('lightblue')
plt.title("Voter Turnout % by County 2010")

# get all upper bounds in the quantiles category
upper_bounds = quantiles.bins
# get and format all bounds
bounds = []
for index, upper_bound in enumerate(upper_bounds):
    if index == 0:
        lower_bound = fl_counties_trn.trn2010.min()
    else:
        lower_bound = upper_bounds[index-1]

    bound = f'{lower_bound:.2f} - {upper_bound:.2f}'
    bounds.append(bound)

LegendElement = [
                 mpatches.Patch(facecolor='w', hatch='////', edgecolor='k', label = "Low-income area")
                ]

# get all the legend labels
legend_labels = ax.get_legend().get_texts()
# replace the numerical legend labels
for bound, legend_label in zip(bounds, legend_labels):
    legend_label.set_text(bound)

from matplotlib.legend import Legend
leg = Legend(ax, LegendElement, ['Low-income area'],
             loc='lower right', frameon=False)
ax.add_artist(leg)



for x, y, label in zip(fl_cities_big.geometry.x, fl_cities_big.geometry.y, fl_cities_big.city):
    ax.annotate(label, xy=(x, y), xytext=(-15,12), textcoords="offset points", fontsize = 11, color = 'black', 
                bbox=dict(boxstyle="round", ec=(1.,0.5,0.5), fc=(1., 0.8, 0.8)))

# %%
# categorize the numerical column
k = 6
quantiles = mc.Quantiles(fl_counties_trn.trn2012.dropna(), k=k)
fl_counties_trn['qnt2012'] = quantiles.find_bin(fl_counties_trn.trn2012).astype('str')

fl_counties_trn.loc[fl_counties_trn.trn2012.isnull(), 'qnt2012'] = 'No Data'

# add grey to a colormap to represent missing value
cmap = plt.cm.get_cmap('RdYlGn', k)
cmap_list = [rgb2hex(cmap(i)) for i in range(cmap.N)]
cmap_list.append('grey')
cmap_with_grey = colors.ListedColormap(cmap_list)

fig, ax = plt.subplots(figsize = (12,12))
ax.set_aspect('equal')
fl_counties_trn.plot(ax = ax, column='qnt2012', cmap = cmap_with_grey, edgecolor='black', legend=True)
fl_counties_pov[fl_counties_pov["pov2012"] >= 20].plot(ax = ax, facecolor='none', edgecolor = 'black', hatch="//")
fl_cities_big.plot(ax = ax, facecolor = 'black')

ax.set_facecolor('lightblue')
plt.title("Voter Turnout % by County 2012")

# get all upper bounds in the quantiles category
upper_bounds = quantiles.bins
# get and format all bounds
bounds = []
for index, upper_bound in enumerate(upper_bounds):
    if index == 0:
        lower_bound = fl_counties_trn.trn2012.min()
    else:
        lower_bound = upper_bounds[index-1]

    bound = f'{lower_bound:.2f} - {upper_bound:.2f}'
    bounds.append(bound)

LegendElement = [
                 mpatches.Patch(facecolor='w', hatch='////', edgecolor='k', label = "Low-income area")
                ]

# get all the legend labels
legend_labels = ax.get_legend().get_texts()
# replace the numerical legend labels
for bound, legend_label in zip(bounds, legend_labels):
    legend_label.set_text(bound)

from matplotlib.legend import Legend
leg = Legend(ax, LegendElement, ['Low-income area'],
             loc='lower right', frameon=False)
ax.add_artist(leg)

for x, y, label in zip(fl_cities_big.geometry.x, fl_cities_big.geometry.y, fl_cities_big.city):
    ax.annotate(label, xy=(x, y), xytext=(-15,12), textcoords="offset points", fontsize = 11, color = 'black', 
                bbox=dict(boxstyle="round", ec=(1.,0.5,0.5), fc=(1., 0.8, 0.8)))

# %%
# categorize the numerical column
k = 6
quantiles = mc.Quantiles(fl_counties_trn.trn2014.dropna(), k=k)
fl_counties_trn['qnt2014'] = quantiles.find_bin(fl_counties_trn.trn2014).astype('str')

fl_counties_trn.loc[fl_counties_trn.trn2014.isnull(), 'qnt2014'] = 'No Data'

# add grey to a colormap to represent missing value
cmap = plt.cm.get_cmap('RdYlGn', k)
cmap_list = [rgb2hex(cmap(i)) for i in range(cmap.N)]
cmap_list.append('grey')
cmap_with_grey = colors.ListedColormap(cmap_list)

fig, ax = plt.subplots(figsize = (12,12))
ax.set_aspect('equal')
fl_counties_trn.plot(ax = ax, column='qnt2014', cmap = cmap_with_grey, edgecolor='black', legend=True)
fl_counties_pov[fl_counties_pov["pov2014"] >= 20].plot(ax = ax, facecolor='none', edgecolor = 'black', hatch="//")
fl_cities_big.plot(ax = ax, facecolor = 'black')

ax.set_facecolor('lightblue')
plt.title("Voter Turnout % by County 2014")

# get all upper bounds in the quantiles category
upper_bounds = quantiles.bins
# get and format all bounds
bounds = []
for index, upper_bound in enumerate(upper_bounds):
    if index == 0:
        lower_bound = fl_counties_trn.trn2014.min()
    else:
        lower_bound = upper_bounds[index-1]

    bound = f'{lower_bound:.2f} - {upper_bound:.2f}'
    bounds.append(bound)

LegendElement = [
                 mpatches.Patch(facecolor='w', hatch='////', edgecolor='k', label = "Low-income area")
                ]

# get all the legend labels
legend_labels = ax.get_legend().get_texts()
# replace the numerical legend labels
for bound, legend_label in zip(bounds, legend_labels):
    legend_label.set_text(bound)

from matplotlib.legend import Legend
leg = Legend(ax, LegendElement, ['Low-income area'],
             loc='lower right', frameon=False)
ax.add_artist(leg)

for x, y, label in zip(fl_cities_big.geometry.x, fl_cities_big.geometry.y, fl_cities_big.city):
    ax.annotate(label, xy=(x, y), xytext=(-15,12), textcoords="offset points", fontsize = 11, color = 'black', 
                bbox=dict(boxstyle="round", ec=(1.,0.5,0.5), fc=(1., 0.8, 0.8)))

# %%
# categorize the numerical column
k = 6
quantiles = mc.Quantiles(fl_counties_trn.trn2016.dropna(), k=k)
fl_counties_trn['qnt2016'] = quantiles.find_bin(fl_counties_trn.trn2016).astype('str')

fl_counties_trn.loc[fl_counties_trn.trn2016.isnull(), 'qnt2016'] = 'No Data'

# add grey to a colormap to represent missing value
cmap = plt.cm.get_cmap('RdYlGn', k)
cmap_list = [rgb2hex(cmap(i)) for i in range(cmap.N)]
cmap_list.append('grey')
cmap_with_grey = colors.ListedColormap(cmap_list)

fig, ax = plt.subplots(figsize = (12,12))
ax.set_aspect('equal')
fl_counties_trn.plot(ax = ax, column='qnt2016', cmap = cmap_with_grey, edgecolor='black', legend=True)
fl_counties_pov[fl_counties_pov["pov2016"] >= 20].plot(ax = ax, facecolor='none', edgecolor = 'black', hatch="//")
fl_cities_big.plot(ax = ax, facecolor = 'black')

ax.set_facecolor('lightblue')
plt.title("Voter Turnout % by County 2016")

# get all upper bounds in the quantiles category
upper_bounds = quantiles.bins
# get and format all bounds
bounds = []
for index, upper_bound in enumerate(upper_bounds):
    if index == 0:
        lower_bound = fl_counties_trn.trn2016.min()
    else:
        lower_bound = upper_bounds[index-1]

    bound = f'{lower_bound:.2f} - {upper_bound:.2f}'
    bounds.append(bound)

LegendElement = [
                 mpatches.Patch(facecolor='w', hatch='////', edgecolor='k', label = "Low-income area")
                ]

# get all the legend labels
legend_labels = ax.get_legend().get_texts()
# replace the numerical legend labels
for bound, legend_label in zip(bounds, legend_labels):
    legend_label.set_text(bound)

from matplotlib.legend import Legend
leg = Legend(ax, LegendElement, ['Low-income area'],
             loc='lower right', frameon=False)
ax.add_artist(leg)

for x, y, label in zip(fl_cities_big.geometry.x, fl_cities_big.geometry.y, fl_cities_big.city):
    ax.annotate(label, xy=(x, y), xytext=(-15,12), textcoords="offset points", fontsize = 11, color = 'black', 
                bbox=dict(boxstyle="round", ec=(1.,0.5,0.5), fc=(1., 0.8, 0.8)))

# %%
# categorize the numerical column
k = 6
quantiles = mc.Quantiles(fl_counties_trn.trn2018.dropna(), k=k)
fl_counties_trn['qnt2018'] = quantiles.find_bin(fl_counties_trn.trn2018).astype('str')

fl_counties_trn.loc[fl_counties_trn.trn2018.isnull(), 'qnt2018'] = 'No Data'

# add grey to a colormap to represent missing value
cmap = plt.cm.get_cmap('RdYlGn', k)
cmap_list = [rgb2hex(cmap(i)) for i in range(cmap.N)]
cmap_list.append('grey')
cmap_with_grey = colors.ListedColormap(cmap_list)

fig, ax = plt.subplots(figsize = (12,12))
ax.set_aspect('equal')
fl_counties_trn.plot(ax = ax, column='qnt2018', cmap = cmap_with_grey, edgecolor='black', legend=True)
fl_counties_pov[fl_counties_pov["pov2018"] >= 20].plot(ax = ax, facecolor='none', edgecolor = 'black', hatch="//")
fl_cities_big.plot(ax = ax, facecolor = 'black')

ax.set_facecolor('lightblue')
plt.title("Voter Turnout % by County 2018")

# get all upper bounds in the quantiles category
upper_bounds = quantiles.bins
# get and format all bounds
bounds = []
for index, upper_bound in enumerate(upper_bounds):
    if index == 0:
        lower_bound = fl_counties_trn.trn2018.min()
    else:
        lower_bound = upper_bounds[index-1]

    bound = f'{lower_bound:.2f} - {upper_bound:.2f}'
    bounds.append(bound)

LegendElement = [
                 mpatches.Patch(facecolor='w', hatch='////', edgecolor='k', label = "Low-income area")
                ]

# get all the legend labels
legend_labels = ax.get_legend().get_texts()
# replace the numerical legend labels
for bound, legend_label in zip(bounds, legend_labels):
    legend_label.set_text(bound)

from matplotlib.legend import Legend
leg = Legend(ax, LegendElement, ['Low-income area'],
             loc='lower right', frameon=False)
ax.add_artist(leg)

for x, y, label in zip(fl_cities_big.geometry.x, fl_cities_big.geometry.y, fl_cities_big.city):
    ax.annotate(label, xy=(x, y), xytext=(-15,12), textcoords="offset points", fontsize = 11, color = 'black', 
                bbox=dict(boxstyle="round", ec=(1.,0.5,0.5), fc=(1., 0.8, 0.8)))
